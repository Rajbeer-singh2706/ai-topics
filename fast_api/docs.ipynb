# %%
# FastAPI is a modern, high-performance Python web framework. It's built on Starlette (ASGI) and uses Python 
# type hints to auto-generate docs.

# %% [markdown]
# ![image.png](attachment:image.png)
