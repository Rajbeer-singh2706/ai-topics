# %%
## Topic to learn 
'''
  * Fast API 
  * Vector Database & Its Concepts
  * Async Programming 
  
'''

### DEvelop Python Project to make strong hand on ###
# 1. oops 
# 2. Decorator
# 3. Loggin
# 4. retry
# 5. numpy
